# %%
from SPARQLWrapper import SPARQLWrapper, CSV
import pandas as pd
import doi
from datetime import datetime
import sys

# %%
ENDPOINT_URL = "https://www.orkg.org/orkg/triplestore"

PREFIXES =  """
            PREFIX orkgr: <http://orkg.org/orkg/resource/>
            PREFIX orkgc: <http://orkg.org/orkg/class/>
            PREFIX orkgp: <http://orkg.org/orkg/predicate/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
            PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            """

# SPARQL query from the ORKG SPARQL endpoint
# gets papers and respective contributions
query = """   
SELECT ?paper ?paper_title 
       # ?url ?author
       # ?venue ?venue_label
       # ?doi ?publication_month ?publication_year
       # ?research_field ?research_field_label
       # ?contribution
  WHERE {  
    
    # comment out the BINDing line to get the metadata of all papers.
    # BIND(orkgr:R141003 AS ?paper)
    
    # ?paper rdf:type orkgc:Paper;
           rdfs:label ?paper_title ;
           orkgp:P27 ?author ;
           orkgp:P30 ?research_field .
    
    # ?research_field rdfs:label ?research_field_label .
    
    OPTIONAL { ?paper orkgp:P26 ?doi } .
    OPTIONAL { ?paper orkgp:url ?url } .
    OPTIONAL { ?paper orkgp:P28 ?publication_month } .
    OPTIONAL { ?paper orkgp:P29 ?publication_year } .
    OPTIONAL { ?paper orkgp:HAS_VENUE ?venue .
               # ?venue rdfs:label ?venue_label } .
    OPTIONAL { ?paper orkgp:P31 ?contribution } .
}
        """

#Code from Oliver's metadata analysis notebook
user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])

sparql = SPARQLWrapper(ENDPOINT_URL, agent=user_agent)
sparql.setQuery(PREFIXES+query)
sparql.setReturnFormat(CSV)

try:
        results = sparql.queryAndConvert()
except Exception as e:
        print(e)

now = datetime.now()
with open('paper_query_result_' + now.strftime('%Y-%m-%d') + '.csv', 'wb') as file:
        file.write(results)

# %%
orkg_paper_contribution_df = pd.read_csv('paper_query_result_' + now.strftime('%Y-%m-%d') + '.csv', encoding='ISO-8859-1') # no utf-8 encoding ...
orkg_paper_contribution_df = orkg_paper_contribution_df.drop(columns=['paper_title', 'url', 'author', 'venue', 'venue_label', 'publication_month', 'publication_year', 'research_field'])
orkg_paper_contribution_df
# Out:
# C:\Users\wurzbacherm\AppData\Local\Temp\ipykernel_15260\1851233830.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   orkg_paper_contribution_df = pd.read_csv('paper_query_result_' + now.strftime('%Y-%m-%d') + '.csv', encoding='ISO-8859-1') # no utf-8 encoding ...
#                                        paper                            doi  \
# 0       http://orkg.org/orkg/resource/R38466       10.5808/gi.2019.17.2.e14
# 1       http://orkg.org/orkg/resource/R38466       10.5808/gi.2019.17.2.e14
# 2       http://orkg.org/orkg/resource/R38466       10.5808/gi.2019.17.2.e14
# 3       http://orkg.org/orkg/resource/R38466       10.5808/gi.2019.17.2.e14
# 4      http://orkg.org/orkg/resource/R148043  10.1093/bioinformatics/bth227
# ...                                      ...                            ...
# 99995  http://orkg.org/orkg/resource/R537121                            NaN
# 99996  http://orkg.org/orkg/resource/R537121                            NaN
# 99997  http://orkg.org/orkg/resource/R537121                            NaN
# 99998  http://orkg.org/orkg/resource/R537121                            NaN
# 99999  http://orkg.org/orkg/resource/R537121                            NaN
#
#       research_field_label                           contribution
# 0           Bioinformatics   http://orkg.org/orkg/resource/R38472
# 1           Bioinformatics   http://orkg.org/orkg/resource/R38472
# 2           Bioinformatics   http://orkg.org/orkg/resource/R38472
# 3           Bioinformatics   http://orkg.org/orkg/resource/R38472
# 4           Bioinformatics  http://orkg.org/orkg/resource/R148045
# ...                    ...                                    ...
# 99995    Computer Sciences  http://orkg.org/orkg/resource/R537129
# 99996    Computer Sciences  http://orkg.org/orkg/resource/R537133
# 99997    Computer Sciences  http://orkg.org/orkg/resource/R537122
# 99998    Computer Sciences  http://orkg.org/orkg/resource/R537129
# 99999    Computer Sciences  http://orkg.org/orkg/resource/R537133
#
# [100000 rows x 4 columns]

# %%
aggregate_funcs = {'paper': 'first', 'doi': 'first', 'research_field_label': 'first'}
orkg_paper_df = orkg_paper_contribution_df.groupby('paper', as_index=False).agg(aggregate_funcs)
orkg_paper_df
# Out:
#                                        paper                            doi  \
# 0        http://orkg.org/orkg/resource/R1004      10.1186/s12866-016-0676-9
# 1      http://orkg.org/orkg/resource/R108458                           None
# 2      http://orkg.org/orkg/resource/R108460                           None
# 3      http://orkg.org/orkg/resource/R108462                           None
# 4      http://orkg.org/orkg/resource/R108464                           None
# ...                                      ...                            ...
# 12988    http://orkg.org/orkg/resource/R8441  10.1016/j.jbiotec.2013.12.009
# 12989    http://orkg.org/orkg/resource/R9154        10.1073/pnas.1913007117
# 12990    http://orkg.org/orkg/resource/R9190    10.1007/978-3-319-54064-1_3
# 12991    http://orkg.org/orkg/resource/R9295         10.1038/nprot.2016.182
# 12992    http://orkg.org/orkg/resource/R9639   10.1007/978-3-030-30760-8_18
#
#       research_field_label
# 0           Bioinformatics
# 1                  Science
# 2                  Science
# 3                  Science
# 4                  Science
# ...                    ...
# 12988      Systems Biology
# 12989        Life Sciences
# 12990        Biotechnology
# 12991        Biotechnology
# 12992    Computer Sciences
#
# [12993 rows x 3 columns]

# %%
def check_doi(orkg_doi):
    try:
        doi.validate_doi(orkg_doi)
    except:
        return None
    return orkg_doi

orkg_paper_df['doi'] = orkg_paper_df['doi'].map(lambda x: check_doi(x))
orkg_paper_df = orkg_paper_df.dropna()
orkg_paper_df.reset_index(drop=True, inplace=True)

orkg_paper_df.to_pickle("./orkg_papers_"+now.strftime('%Y-%m-%d')+".pkl")
orkg_paper_df
# Out:
#                                       paper                            doi  \
# 0       http://orkg.org/orkg/resource/R1004      10.1186/s12866-016-0676-9
# 1     http://orkg.org/orkg/resource/R108529        10.1145/3201064.3201083
# 2     http://orkg.org/orkg/resource/R108704     10.1094/pdis-02-15-0236-re
# 3     http://orkg.org/orkg/resource/R108713      10.1007/s10658-014-0409-6
# 4     http://orkg.org/orkg/resource/R108865      10.1186/s12859-019-3284-5
# ...                                     ...                            ...
# 4430    http://orkg.org/orkg/resource/R8441  10.1016/j.jbiotec.2013.12.009
# 4431    http://orkg.org/orkg/resource/R9154        10.1073/pnas.1913007117
# 4432    http://orkg.org/orkg/resource/R9190    10.1007/978-3-319-54064-1_3
# 4433    http://orkg.org/orkg/resource/R9295         10.1038/nprot.2016.182
# 4434    http://orkg.org/orkg/resource/R9639   10.1007/978-3-030-30760-8_18
#
#      research_field_label
# 0          Bioinformatics
# 1       Computer Sciences
# 2         Plant Pathology
# 3         Plant Pathology
# 4          Bioinformatics
# ...                   ...
# 4430      Systems Biology
# 4431        Life Sciences
# 4432        Biotechnology
# 4433        Biotechnology
# 4434    Computer Sciences
#
# [4435 rows x 3 columns]

# %%
ENDPOINT_URL = "https://www.orkg.org/orkg/triplestore"

PREFIXES =  """
            PREFIX orkgr: <http://orkg.org/orkg/resource/>
            PREFIX orkgc: <http://orkg.org/orkg/class/>
            PREFIX orkgp: <http://orkg.org/orkg/predicate/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
            PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
            PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            """

# SPARQL query from the ORKG SPARQL endpoint
# gets papers and respective contributions
query = """   
SELECT ?comparisons ?doi
        WHERE {
            # ?comparisons rdf:type orkgc:Comparison .   
            OPTIONAL { ?comparisons orkgp:P26 ?doi }
        }
        """

#Code from Oliver's metadata analysis notebook
user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])

sparql = SPARQLWrapper(ENDPOINT_URL, agent=user_agent)
sparql.setQuery(PREFIXES+query)
sparql.setReturnFormat(CSV)

try:
        results = sparql.queryAndConvert()
except Exception as e:
        print(e)

now = datetime.now()
with open('comparison_query_result_' + now.strftime('%Y-%m-%d') + '.csv', 'wb') as file:
        file.write(results)

# %%
orkg_comparison_df = pd.read_csv('comparison_query_result_' + now.strftime('%Y-%m-%d') + '.csv', encoding='ISO-8859-1') # no utf-8 encoding ...
orkg_comparison_df = orkg_comparison_df.dropna()
orkg_comparison_df.reset_index(drop=True, inplace=True)

orkg_comparison_df.to_pickle("./orkg_comparisons_"+now.strftime('%Y-%m-%d')+".pkl")
orkg_comparison_df
# Out:
#                                comparisons               doi
# 0     http://orkg.org/orkg/resource/R36099   10.48366/r36099
# 1     http://orkg.org/orkg/resource/R38484   10.48366/r38484
# 2     http://orkg.org/orkg/resource/R44930   10.48366/r44930
# 3     http://orkg.org/orkg/resource/R70212   10.48366/r70212
# 4      http://orkg.org/orkg/resource/R8342    10.48366/r8342
# ..                                     ...               ...
# 282  http://orkg.org/orkg/resource/R284515  10.48366/r284515
# 283  http://orkg.org/orkg/resource/R285347  10.48366/r285347
# 284  http://orkg.org/orkg/resource/R287928  10.48366/r287928
# 285  http://orkg.org/orkg/resource/R287929  10.48366/r287929
# 286  http://orkg.org/orkg/resource/R385010  10.48366/r385010
#
# [287 rows x 2 columns]
